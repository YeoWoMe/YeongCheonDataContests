# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
middle_school = pd.read_csv("/content/drive/Othercomputers/내 노트북/DNA/영천시 공모전/final_dataframe/중학교_final.csv")
kindergarden = pd.read_csv("/content/drive/Othercomputers/내 노트북/DNA/영천시 공모전/final_dataframe/어린이집_final.csv")
child = pd.read_csv("/content/drive/Othercomputers/내 노트북/DNA/영천시 공모전/final_dataframe/유치원_final.csv")
pub_medical = pd.read_csv("/content/drive/Othercomputers/내 노트북/DNA/영천시 공모전/final_dataframe/20210726_영천시_보건소보건의료원_final.csv")
emergency_medical = pd.read_csv("/content/drive/Othercomputers/내 노트북/DNA/영천시 공모전/final_dataframe/20220826_영천시_응급의료기관_final.csv")

# %%
#시각화 글꼴 깨짐 방지
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 1s (10.0 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
import matplotlib.pyplot as plt #실행 전 런타임 다시 시작

plt.rc('font', family='NanumGothic')

# 음수 부호까지 제대로 표시되도록 설정 추가
plt.rcParams['axes.unicode_minus'] = False

# %%
#필요한 라이브러리 불러오기
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#plotly 시각화 라이브러리
import plotly.express as px
import plotly.io as pio
import plotly.graph_objects as go
from plotly.subplots import make_subplots #서브플롯 제작

#warning 알림 무시
import warnings
warnings.filterwarnings('ignore')

# %%
people = pd.read_excel("/content/drive/Othercomputers/내 노트북/DNA/영천시 공모전/youngcheon_data/행정구역_읍면동_별_5세별_주민등록인구.xlsx")

# %%
air2021 = pd.read_csv("/content/drive/Othercomputers/내 노트북/DNA/영천시 공모전/youngcheon_data/대기오염_2021.csv")
air2020 = pd.read_csv("/content/drive/Othercomputers/내 노트북/DNA/영천시 공모전/youngcheon_data/대기오염_2020.csv")
air2019 = pd.read_csv("/content/drive/Othercomputers/내 노트북/DNA/영천시 공모전/youngcheon_data/대기오염_2019.csv")
air2018 = pd.read_csv("/content/drive/Othercomputers/내 노트북/DNA/영천시 공모전/youngcheon_data/대기오염_2018.csv")
air2017 = pd.read_csv("/content/drive/Othercomputers/내 노트북/DNA/영천시 공모전/youngcheon_data/대기오염_2017.csv")

# %%
people['15세미만'] =  people.iloc[:, 2:5].sum(axis=1)
people['15_64세'] = people.iloc[:,5:15].sum(axis=1)
people['65세이상'] = people.iloc[:,15:23].sum(axis=1)
people['85세이상'] = people.iloc[:,19:23].sum(axis=1)

people['10대 미만'] = people.iloc[:,2:4].sum(axis=1)
people['10대'] = people.iloc[:,4:6].sum(axis=1)
people['20대'] = people.iloc[:,6:8].sum(axis=1)
people['30대'] = people.iloc[:,8:10].sum(axis=1)
people['40대'] = people.iloc[:,10:12].sum(axis=1)
people['50대'] = people.iloc[:,12:14].sum(axis=1)
people['60대'] = people.iloc[:,14:16].sum(axis=1)
people['70대'] = people.iloc[:,16:18].sum(axis=1)
people['80대'] = people.iloc[:,18:20].sum(axis=1)
people['90대'] = people.iloc[:,20:22].sum(axis=1)
people['100세이상'] = people.iloc[:,22:23].sum(axis=1)

people = people[['행정구역(동읍면)별','계','15세미만',
       '15_64세', '65세이상', '85세이상', '10대 미만', '10대', '20대', '30대', '40대', '50대',
       '60대', '70대', '80대', '90대', '100세이상']]

# %%
sns.barplot(x="행정구역(동읍면)별", y="15_64세", color="cornflowerblue",data=except_people, order=except_people.sort_values('15_64세', ascending=False)['행정구역(동읍면)별'])
plt.xticks(rotation=90)
plt.title("행정구역별 15~64세 인구")
plt.xlabel("읍면동")
plt.ylabel("count")
plt.show()

# %%
plt.figure(figsize=(20, 20))
sorted_except_people = except_people.sort_values("계", ascending=False)
# Plot the sorted DataFrame
sorted_except_people[["행정구역(동읍면)별", "계", "15세미만", "65세이상"]].plot(x="행정구역(동읍면)별", kind="bar",width=0.8)
plt.title("인구별 비교")
plt.xlabel("읍면동")
plt.ylabel("count")
plt.show()

# %%
air2021
# Out:
#       emd_code   CO1      CO2   PM   NOx  VOCs  읍면동    년도
# 2929   3707011  3463  2394732  124  4000   537  금호읍  2021
# 2930   3707031  1996  1511535   65  2163   289  청통면  2021
# 2931   3707032  3066  2680376  133  4454   574  신녕면  2021
# 2932   3707033  2682  2351204  111  3699   463  화산면  2021
# 2933   3707034   592   303480   17   621   125  화북면  2021
# 2934   3707035  2350  1996920   79  2639   322  화남면  2021
# 2935   3707036   385   176231   11   425   106  자양면  2021
# 2936   3707037  2705  2301379   91  3014   347  임고면  2021
# 2937   3707038  2181  1701416   86  2902   414  고경면  2021
# 2938   3707039  4424  3950900  199  6336   709  북안면  2021
# 2939   3707040  2255  1911154  101  3208   380  대창면  2021
# 2940   3707051  3823  1754297   83  3381   816  동부동  2021
# 2941   3707052  3743  2394331  104  3745   630  중앙동  2021
# 2942   3707053  3372  1466677   64  2413   521  서부동  2021
# 2943   3707054  5304  1479312   49  2573   896  완산동  2021
# ...

# %%
air2020.head()
air2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16 entries, 2922 to 2937
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   emd_code  16 non-null     int64
#  1   CO1       16 non-null     int64
#  2   CO2       16 non-null     int64
#  3   PM        16 non-null     int64
#  4   NOx       16 non-null     int64
#  5   VOCs      16 non-null     int64
#  6   읍면동       16 non-null     object
#  7   년도        16 non-null     int64
# dtypes: int64(7), object(1)
# memory usage: 1.1+ KB

# %%
air2019.head(3)
air2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16 entries, 2940 to 2955
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   emd_code  16 non-null     int64
#  1   CO1       16 non-null     int64
#  2   CO2       16 non-null     int64
#  3   PM        16 non-null     int64
#  4   NOx       16 non-null     int64
#  5   VOCs      16 non-null     int64
#  6   읍면동       16 non-null     object
#  7   년도        16 non-null     int64
# dtypes: int64(7), object(1)
# memory usage: 1.1+ KB

# %%
air2017.head(2)
air2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sido_code     16 non-null     int64
#  1   sigungu_code  16 non-null     int64
#  2   emd_code      16 non-null     int64
#  3   week_type     16 non-null     object
#  4   CO1           16 non-null     int64
#  5   CO2           16 non-null     int64
#  6   PM            16 non-null     int64
#  7   NOx           16 non-null     int64
#  8   VOCs          16 non-null     int64
#  9   읍면동           16 non-null     object
# dtypes: int64(8), object(2)
# memory usage: 1.4+ KB

# %%
air2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16 entries, 161 to 3092
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   emd_code  16 non-null     int64
#  1   CO1       16 non-null     int64
#  2   CO2       16 non-null     int64
#  3   PM        16 non-null     int64
#  4   NOx       16 non-null     int64
#  5   VOCs      16 non-null     int64
#  6   읍면동       16 non-null     object
#  7   년도        16 non-null     int64
# dtypes: int64(7), object(1)
# memory usage: 1.1+ KB

# %%
air2019 = air2019.rename(columns={'ALL_CO1':'CO1', 'ALL_CO2':"CO2", "ALL_PM":"PM",
                                  "ALL_NOx":"NOx","ALL_VOCs":"VOCs"})

# %%
air_datas = [air2021, air2020, air2019, air2018, air2017]
for d in air_datas:
  d.drop(columns=['sido_code',"sigungu_code"],axis=1, inplace=True)

# %%
for d in air_datas:
  d.drop(columns=['week_type'],axis=1, inplace=True)

# %%
code = [3707011, 3707031, 3707032, 3707033, 3707034, 3707035, 3707036,
        3707037, 3707038, 3707039, 3707040, 3707051, 3707052, 3707053,
        3707054, 3707055]

name = ["금호읍","청통면", "신녕면", "화산면", "화북면", "화남면", "자양면", "임고면", "고경면",
        "북안면", "대창면", "동부동", "중앙동", "서부동", "완산동","남부동"]

for c, n in zip(code, name):
    air2018.loc[air2018["emd_code"] == c, "읍면동"] = n

# Print the DataFrame to check the changes
air2019 = air2018.loc[air2018["sigungu_code"]==37070]

# %%
air2021['년도'] = 2021
air2020['년도'] = 2020
air2019['년도'] = 2019
air2018['년도'] = 2018
air2017['년도'] = 2017

# %%
for d in air_datas:
  print(d.shape)
# Out:
# (16, 7)
# (16, 7)
# (16, 7)
# (16, 7)
# (16, 7)

# %%
air_datas = [air2021, air2020, air2019, air2018, air2017]

# %%
air = pd.concat(air_datas)
air.reset_index(inplace=True)

# %%
air.info()
air= air[['읍면동','년도','emd_code','CO1','CO2','PM','NOx','VOCs']]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   emd_code  80 non-null     int64
#  1   CO1       80 non-null     int64
#  2   CO2       80 non-null     int64
#  3   PM        80 non-null     int64
#  4   NOx       80 non-null     int64
#  5   VOCs      80 non-null     int64
#  6   읍면동       80 non-null     object
#  7   년도        80 non-null     int64
# dtypes: int64(7), object(1)
# memory usage: 5.1+ KB

# %%
air.drop(['index'], axis=1, inplace=True)

# %%
sns.barplot(x="읍면동", y="ALL_PM",data=air, order=air.sort_values('ALL_PM', ascending=False)['읍면동'])
plt.xticks(rotation=90)
plt.title("행정구역별 미세먼지")
plt.xlabel("")
plt.ylabel("g/일",loc="bottom")
plt.show()

# %%
## 활성화지수 전처리
flourishing = pd.read_csv("/content/drive/Othercomputers/내 노트북/DNA/DNA/영천시 공모전/youngcheon_data/국토교통부_활성화지역진단지표읍면동_2022.csv", encoding="cp949")

# %%
flourishing = flourishing.loc[flourishing['시군구명']=="경상북도 영천시"]

# %%
flourishing
# Out:
#      읍면동    연도   과거대비인구변화  최근인구변화  과거대비사업체변화  최근사업체변화    노후건축물비율
# 0    금호읍  2013 -37.485084       2   4.930663        1  58.678238
# 1    청통면  2013 -57.493580       2   0.983607        1  43.996469
# 2    신녕면  2013 -58.709872       2  -4.777070        2  61.941552
# 3    화산면  2013 -64.574492       2   3.731343        1  59.151973
# 4    화북면  2013 -85.131841       4 -19.327731        1  54.945718
# ..   ...   ...        ...     ...        ...      ...        ...
# 123  동부동  2021  -0.211175       4  68.703828        1  60.742019
# 124  중앙동  2021   0.516740       3  21.493441        1  59.112452
# 125  서부동  2021 -41.558935       5  36.229508        1  66.974596
# 126  완산동  2021 -25.727934       1   8.148148        2  65.993266
# 127  남부동  2021 -14.833980       3  40.711009        0  50.035791
#
# [128 rows x 7 columns]

# %%
flourishing = flourishing.iloc[:,5:]
flourishing.reset_index(inplace=True)
flourishing.drop(['index'], axis=1,inplace=True)
flourishing.rename(columns={'읍면동명':'읍면동'}, inplace=True)

# %%
data = pd.read_excel("/content/drive/Othercomputers/내 노트북/DNA/DNA/영천시 공모전/youngcheon_data/읍면동별_산업대분류별_총괄_20240514181706.xlsx")

# %%
data.drop(["산업분류별"],axis=1, inplace=True)

# %%
down =  pd.read_excel("/content/drive/Othercomputers/내 노트북/DNA/DNA/영천시 공모전/youngcheon_data/쇠퇴지수.xlsx")

# %%
down.columns
# Out:
# Index(['연도', '읍면동명', '인구변화율(인구총조사)', '인구변화율(인구총조사)등급', '노령화지수(인구총조사)',
#        '노령화지수(인구총조사)등급', '종사자수(천명당)', '종사자수(천명당)등급', '사업체당종사자수', '사업체당종사자수등급',
#        '제조업종사자비율', '제조업종사자비율등급', '도소매업종사자수(천명당)', '도소매업종사자수(천명당)등급', '소형주택비율',
#        '소형주택비율등급', '노후주택비율', '노후주택비율등급', '신규주택비율', '신규주택비율등급',
#        '인구변화율(주민등록인구통계)', '인구변화율(주민등록인구통계)등급', '노령화지수(주민등록인구통계)',
#        '노령화지수(주민등록인구통계)등급', '고령인구수(인구총조사)', '고령인구수(인구총조사)등급',
#        '고령인구수(주민등록인구통계)', '고령인구수(주민등록인구통계)등급', '노년부양비(인구총조사)',
#        '노년부양비(인구총조사)등급', '노년부양비(주민등록인구통계)', '노년부양비(주민등록인구통계)등급',
#        '경제활동인구(인구총조사)', '경제활동인구(인구총조사)등급', '경제활동인구(주민등록인구통계)',
#        '경제활동인구(주민등록인구통계)등급', '총사업체수증감율', '총사업체수증감율등급', '총종사자수증감율',
#        '총종사자수증감율등급', '고차산업종사자비율', '고차산업종사자비율등급', '주요산업별종사자수', '주요산업별종사자수등급',
#        '총사업체수', '총사업체수등급', '부동산공시지가', '부동산공시지가등급', '접도율', '접도율등급', '노후건축물비율',
#        '노후건축물비율등급', '도소매업체증감율', '도소매업체증감율등급', '제조업체증감율', '제조업체증감율등급'],
#       dtype='object')

# %%
down_grade = down[['연도','읍면동명','사업체당종사자수등급','제조업종사자비율등급','도소매업종사자수(천명당)등급','소형주택비율등급','노후주택비율등급','신규주택비율등급',
     '인구변화율(주민등록인구통계)등급','노령화지수(주민등록인구통계)등급','고령인구수(주민등록인구통계)등급','노년부양비(주민등록인구통계)등급',
     '경제활동인구(주민등록인구통계)등급','총사업체수증감율등급','총종사자수증감율등급','고차산업종사자비율등급',
     '주요산업별종사자수등급','총사업체수등급','부동산공시지가등급','접도율등급','노후건축물비율등급','도소매업체증감율등급','제조업체증감율등급']]

# %%
down_grade.to_excel("쇠퇴등급.xlsx", index=False)

# %%
a = dict(down_grade.isnull().sum())
l = pd.DataFrame()

for key, value in a.items():
  if value == 0:
    print(key)
# Out:
# 연도
# 읍면동명
# 소형주택비율등급
# 노후주택비율등급
# 신규주택비율등급
# 인구변화율(주민등록인구통계)등급
# 노령화지수(주민등록인구통계)등급
# 고령인구수(주민등록인구통계)등급
# 노년부양비(주민등록인구통계)등급
# 경제활동인구(주민등록인구통계)등급
# 부동산공시지가등급
# 접도율등급
# 노후건축물비율등급

# %%
# ?pd.DataFrame

# %%
down.columns
# Out:
# Index(['연도', '읍면동명', '인구변화율(인구총조사)', '인구변화율(인구총조사)등급', '노령화지수(인구총조사)',
#        '노령화지수(인구총조사)등급', '종사자수(천명당)', '종사자수(천명당)등급', '사업체당종사자수', '사업체당종사자수등급',
#        '제조업종사자비율', '제조업종사자비율등급', '도소매업종사자수(천명당)', '도소매업종사자수(천명당)등급', '소형주택비율',
#        '소형주택비율등급', '노후주택비율', '노후주택비율등급', '신규주택비율', '신규주택비율등급',
#        '인구변화율(주민등록인구통계)', '인구변화율(주민등록인구통계)등급', '노령화지수(주민등록인구통계)',
#        '노령화지수(주민등록인구통계)등급', '고령인구수(인구총조사)', '고령인구수(인구총조사)등급',
#        '고령인구수(주민등록인구통계)', '고령인구수(주민등록인구통계)등급', '노년부양비(인구총조사)',
#        '노년부양비(인구총조사)등급', '노년부양비(주민등록인구통계)', '노년부양비(주민등록인구통계)등급',
#        '경제활동인구(인구총조사)', '경제활동인구(인구총조사)등급', '경제활동인구(주민등록인구통계)',
#        '경제활동인구(주민등록인구통계)등급', '총사업체수증감율', '총사업체수증감율등급', '총종사자수증감율',
#        '총종사자수증감율등급', '고차산업종사자비율', '고차산업종사자비율등급', '주요산업별종사자수', '주요산업별종사자수등급',
#        '총사업체수', '총사업체수등급', '부동산공시지가', '부동산공시지가등급', '접도율', '접도율등급', '노후건축물비율',
#        '노후건축물비율등급', '도소매업체증감율', '도소매업체증감율등급', '제조업체증감율', '제조업체증감율등급'],
#       dtype='object')

# %%
down=down[['읍면동명', '연도','인구변화율(인구총조사)',
       '인구변화율(인구총조사)등급', '노령화지수(인구총조사)', '노령화지수(인구총조사)등급', '종사자수(천명당)',
       '종사자수(천명당)등급', '사업체당종사자수', '사업체당종사자수등급', '제조업종사자비율', '제조업종사자비율등급',
       '도소매업종사자수(천명당)', '도소매업종사자수(천명당)등급', '소형주택비율', '소형주택비율등급', '노후주택비율',
       '노후주택비율등급', '신규주택비율', '신규주택비율등급', '인구변화율(주민등록인구통계)',
       '인구변화율(주민등록인구통계)등급', '노령화지수(주민등록인구통계)', '노령화지수(주민등록인구통계)등급',
       '고령인구수(인구총조사)', '고령인구수(인구총조사)등급', '고령인구수(주민등록인구통계)',
       '고령인구수(주민등록인구통계)등급', '노년부양비(인구총조사)', '노년부양비(인구총조사)등급',
       '노년부양비(주민등록인구통계)', '노년부양비(주민등록인구통계)등급', '경제활동인구(인구총조사)',
       '경제활동인구(인구총조사)등급', '경제활동인구(주민등록인구통계)', '경제활동인구(주민등록인구통계)등급', '총사업체수증감율',
       '총사업체수증감율등급', '총종사자수증감율', '총종사자수증감율등급', '고차산업종사자비율', '고차산업종사자비율등급',
       '주요산업별종사자수', '주요산업별종사자수등급', '총사업체수', '총사업체수등급', '부동산공시지가', '부동산공시지가등급',
       '접도율', '접도율등급', '노후건축물비율', '노후건축물비율등급', '도소매업체증감율', '도소매업체증감율등급',
       '제조업체증감율', '제조업체증감율등급', '기초생활수급자(천인당)', '기초생활수급자(천인당)등급']]

# %%
down.sort_values(by="연도")

# %%
people = pd.read_csv("/content/drive/Othercomputers/내 노트북/DNA/DNA/영천시 공모전/final_dataframe/년도별 인구")

# %%
people2019 = people.iloc[:,0:5]
people2020 = people.iloc[:,5:9]
people2021 = people.iloc[:,9:13]
people2022 = people.iloc[:,13:17]

people2019['년도'] = 2019
people2020['년도'] = 2020
people2021['년도'] = 2021
people2022['년도'] = 2022

people2020['항목'] = people.iloc[:,0]
people2021['항목'] = people.iloc[:,0]
people2022['항목'] = people.iloc[:,0]


people2019.rename(columns={"계(2019)":"계", "15세미만(2019)":"15세미만", "15세이상64세미만(2019)":"15세이상65세미만", "65세이상(2019)":"65세이상"}, inplace=True)
people2020.rename(columns={"계(2020)":"계", "15세미만(2020)":"15세미만", "15세이상64세미만(2020)":"15세이상65세미만", "65세이상(2020)":"65세이상"},inplace=True)
people2021.rename(columns={"계(2021)":"계", "15세미만(2021)":"15세미만", "15세이상64세미만(2021)":"15세이상65세미만", "65세이상(2021)":"65세이상"},inplace=True)
people2022.rename(columns={"계(2022)":"계", "15세미만(2022)":"15세미만", "15세이상64세미만(2022)":"15세이상65세미만", "65세이상(2022)":"65세이상"},inplace=True)

# %%
people1 = pd.concat([people2019, people2020, people2021,people2022], axis = 0)
people1.rename(columns={'항목':'읍면동'}, inplace=True)

# %%
people = pd.concat([people1,people2024], axis=0)

# %%
p = p[["읍면동", "계"]]

# %%
people2014 = people.loc[people['년도']==2014]
people2015 = people.loc[people['년도']==2015]
people2016 = people.loc[people['년도']==2016]
people2017 = people.loc[people['년도']==2017]
people2018 = people.loc[people['년도']==2018]
people2019 = people.loc[people['년도']==2019]
people2020 = people.loc[people['년도']==2020]
people2021 = people.loc[people['년도']==2021]
people2022 = people.loc[people['년도']==2022]
people2023 = people.loc[people['년도']==2023]

# %%
#전체 인구로 나눠주기
datas = [people2014, people2015, people2016, people2017, people2018, people2019, people2020, people2021, people2022, people2023]
for d in datas:
  d.reset_index(drop=True, inplace=True)
  d['계'] = d['계'] / ( d['계'][0] )

# %%
main_data = {}

for d, i in zip(datas, range(2013,2024)):
    d['읍면동']=['영천시','금호읍', '청통면', '신녕면', '화산면', '화북면', '화남면',
       '자양면', '임고면', '고경면', '북안면', '대창면', '동부동', '중앙동', '서부동', '완산동',
       '남부동']
    key = 'main{}'.format(i+1)
    main_data[key] = d.loc[d['읍면동'].isin(['서부동', '중앙동', '완산동', '남부동', '동부동'])]

else_data = {}

for d, i in zip(datas, range(2013,2024)):
    key = 'else{}'.format(i+1)
    else_data[key] = d.loc[d['읍면동'].isin(['영천시','서부동', '중앙동', '완산동', '남부동', '동부동']) == False]

for m, i in zip(main_data, range(2014, 2025)):
  globals()[f"main_percent{i}"] = sum(main_data[m]['계'])
for m, i in zip(else_data, range(2014, 2025)):
    globals()[f"else_percent{i}"] = else_data[m]['계'].sum()

# %%
datas
# Out:
# [    읍면동         계  15세미만  15세이상65세미만  65세이상    년도
#  0   영천시  1.000000  10080       66740  23869  2014
#  1   금호읍  0.117769    879        8029   2950  2014
#  2   청통면  0.044027    252        2834   1347  2014
#  3   신녕면  0.042259    245        2565   1445  2014
#  4   화산면  0.033767    159        1958   1283  2014
#  5   화북면  0.021472    113        1210    839  2014
#  6   화남면  0.032506    153        1919   1201  2014
#  7   자양면  0.012275     57         685    494  2014
#  8   임고면  0.043182    237        2482   1629  2014
#  9   고경면  0.059301    479        3574   1918  2014
#  10  북안면  0.046033    217        2695   1723  2014
#  11  대창면  0.031592    156        1992   1033  2014
#  12  동부동  0.278660   4460       20611   2987  2014
#  13  중앙동  0.097498   1489        6814   1514  2014
#  14  서부동  0.054653    458        3700   1345  2014
#  15  완산동  0.045904    416        3082   1124  2014
#  16  남부동  0.039101    310        2590   1037  2014,
# ...

# %%
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot()

ax.plot(people_percent.Year, people_percent.Main_Percents, marker='s', color='tab:blue')
ax.plot(people_percent.Year, people_percent.Else_Percents, marker='o', color='tab:red')

max_main_percent = max(main_percents)
min_else_percent = min(else_percents)

for i in range(len(people_percent['Year'])):
    if people_percent['Main_Percents'][i] == max_main_percent:
        height = people_percent['Main_Percents'][i]
        ax.text(people_percent['Year'][i], height - 0.007, '%.3f' % height, ha='center', va='bottom', size=12, color='black')

    if people_percent['Else_Percents'][i] == min_else_percent:
        height = people_percent['Else_Percents'][i]
        ax.text(people_percent['Year'][i], height + 0.007, '%.3f' % height, ha='center', va='bottom', size=12, color='black')

plt.title('2014년~2023년 시내 5대 읍면동과 이외 읍면동의 인구비율 비교', fontsize=16,pad=20)
plt.xlabel('년도', fontsize=14)
plt.ylabel('인구비율', fontsize=14)
plt.legend(['시내 5대 읍면동', '이외 11개의 읍면동'], fontsize=11, loc='best')

plt.show()

# %%
people2023.reset_index(drop=True, inplace=True)

# %%
import folium

# %%
import os
import geopandas as gpd


bldg_gdf = gpd.read_file('/content/drive/Othercomputers/내 노트북/DNA/DNA/영천시 공모전/youngcheon_data/읍면동구역데이터/emd.shp', encoding='cp949') #EPSG:5181

# %%
data = bldg_gdf[3885:3926]

# %%
print(data.crs) # none
data.set_crs(epsg=5181, inplace=True)
print(data.crs) # 5181
new_data = data.to_crs(epsg=4326)
print(new_data.crs) # 4326
# Out:
# None
# EPSG:5181
# EPSG:4326

# %%
new_data
# Out:
#         EMD_CD        EMD_ENG_NM EMD_KOR_NM  \
# 3885  47230101        Jogyo-dong        조교동
# 3886  47230102    Mangjeong-dong        망정동
# 3887  47230103         Yasa-dong        야사동
# 3888  47230104       Munnae-dong        문내동
# 3889  47230105        Munoe-dong        문외동
# 3890  47230106      Changgu-dong        창구동
# 3891  47230107      Gyochon-dong        교촌동
# 3892  47230108      Gwajeon-dong        과전동
# 3893  47230109     Seongnae-dong        성내동
# 3894  47230110     Hwaryong-dong        화룡동
# 3895  47230111           Do-dong         도동
# 3896  47230112       Geumno-dong        금노동
# 3897  47230113       Wansan-dong        완산동
# 3898  47230114       Beomeo-dong        범어동
# 3899  47230115       Jaksan-dong        작산동
# 3900  47230116         Bong-dong         봉동
# 3901  47230117      Bonchon-dong        본촌동
# 3902  47230118      Chaesin-dong        채신동
# 3903  47230119      Goeyeon-dong        괴연동
# 3904  47230120      Daejeon-dong        대전동
# ...

# %%
bldg_gdf['EMD_CD'] =bldg_gdf['EMD_CD'].astype(int)

# %%
new_data.loc[new_data['EMD_KOR_NM'].isin(['괴연동', '금노동', '도남동', '도동', '범어동', '본촌동', '봉동', '작산동', '채신동']),'EMD_KOR_NM'] = "남부동"
new_data.loc[new_data['EMD_KOR_NM'].isin(['망정동', '신기동', '야사동', '언하동', '조교동']),'EMD_KOR_NM'] ="동부동"
new_data.loc[new_data['EMD_KOR_NM'].isin(['교촌동', '대전동', '서산동', '성내동', '쌍계동', '오수동', '화룡동']),'EMD_KOR_NM'] ="서부동"
new_data.loc[new_data['EMD_KOR_NM'].isin(['과전동', '녹전동', '도림동', '매산동', '문내동', '문외동', '오미동', '창구동']),'EMD_KOR_NM'] ="중앙동"

# %%
data
# Out:
#                                                      geometry    EMD_CD  \
# EMD_KOR_NM
# 고경면         POLYGON ((139.70140 48.78776, 139.70154 48.787...  47230380
# 금호읍         POLYGON ((139.55045 48.74370, 139.55046 48.743...  47230250
# 남부동         POLYGON ((139.65466 48.70665, 139.65467 48.707...  47230111
# 대창면         POLYGON ((139.54859 48.70143, 139.54903 48.701...  47230400
# 동부동         POLYGON ((139.70138 48.78743, 139.70135 48.786...  47230101
# 북안면         POLYGON ((139.68457 48.75142, 139.68460 48.751...  47230390
# 서부동         POLYGON ((139.62249 48.77073, 139.62259 48.771...  47230107
# 신녕면         POLYGON ((139.38234 48.85868, 139.38322 48.858...  47230320
# 완산동         POLYGON ((139.65373 48.77785, 139.65548 48.777...  47230113
# 임고면         POLYGON ((139.69495 48.82699, 139.69547 48.828...  47230370
# 자양면         POLYGON ((139.73811 48.91539, 139.73950 48.916...  47230360
# 중앙동         POLYGON ((139.65316 48.78029, 139.65320 48.780...  47230104
# ...

# %%
#읍면동 기준으로 합쳐주기
data = new_data.dissolve(by='EMD_KOR_NM')

# %%
data.reset_index(inplace=True)

# %%
new_data.plot()
# Out:
# <Axes: >

# %%
p.rename(columns={'읍면동':'EMD_KOR_NM'},inplace=True)

# %%
data['people'] = [5687,10449,3941,3022,27252,4398,4548,3662,9975,4133,1324,9401,3964,3182,2216,3058]

# %%
data.columns
# Out:
# Index(['EMD_KOR_NM', 'geometry', 'EMD_CD', 'EMD_ENG_NM'], dtype='object')

# %%
ax = data.plot(figsize=(10, 10), column="people", categorical=False,
                   cmap="PuBu", edgecolor="k", legend=True)
for idx, row in data.iterrows():
    ax.text(row.geometry.centroid.x, row.geometry.centroid.y, str(row['EMD_KOR_NM']),
            ha='center', va='bottom', size=10, color='black',bbox=dict(facecolor='white', alpha=0.8, edgecolor='black'))
ax.set_axis_off()
plt.show()

# %% [markdown]
# ##지오코딩

# %%
import json
import requests

# %%
headers = {"Authorization": "1c28c3622f120723a295ad5c1c8977e2"}

# %%
#지오코딩
def get_coordinate(address): # 주소를 입력받음
    result = ""

    url = 'https://dapi.kakao.com/v2/local/search/address.json?query=' + address # 카카오 api 서버스를 이용하여 접근
    rest_api_key = '1c28c3622f120723a295ad5c1c8977e2' # 사용자 api key
    header = {'Authorization': 'KakaoAK ' + rest_api_key}

    r = requests.get(url, headers=header)
    if r.status_code == 200: # 정보를 오류없이 받아왔다면
        if len(r.json()['documents']) != 0: # 길이가 0이 아니라면
            try :
                result_address = r.json()["documents"][0]["address"]
                result = (result_address["y"],result_address["x"], result_address['region_3depth_h_name'], result_address['region_3depth_name'],result_address['b_code'] )  # 좌표 정보에 접근
            except:  # 예외처리
                result = np.nan

        else: # 길이가 0인경우 na처리
            result = np.nan

    else:
        result = "ERROR[" + str(r.status_code) + "]"


    return result # 좌표를 반환

# %%
def transform(data, address_feature):
    data['법정동'] =""
    data['법정리'] = ""
    data['법정코드'] =""
    for i in range(len(data)):
        result = get_coordinate(data[address_feature][i])

        if result is np.nan:
            continue

        else:
            data['위도'][i] = result[0]
            data['경도'][i] = result[1]
            data['법정동'][i] = result[2]
            data['법정리'][i] = result[3]
            data['법정코드'][i] = result[4]


    x = data['법정리'].str.split()
    print(x)

    for i in range(len(x)):

      if len(x[i]) ==  1:
        data.loc[i, '법정리'] = x.iloc[i][0]
      elif len(x[i]) ==  2:
        data.loc[i, '법정리'] = x.iloc[i][1]

    return data

# %%
transform(pub_medical, '도로명주소')
# Out:
# 0    [문내동]
# Name: 법정리, dtype: object
# <ipython-input-48-eadee1b06860>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['위도'][i] = result[0]
# <ipython-input-48-eadee1b06860>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['경도'][i] = result[1]
#       보건소명              도로명주소       지번주소                위도                경도  \
# 0  영천시 보건소  경상북도 영천시 옛군청1길 31  문내동 152-1  35.9687454982593  128.932401426603
#
#   법정동명  법정동  법정리        법정코드
# 0  문내동  중앙동  문내동  4723010400

# %%
kindergarden.loc[kindergarden['어린이집명']=="예쁜어린이집", ['법정동','법정리','법정코드']] = ['금호읍','교대리',4723025021]

# %%
middle_school.head(2)
# Out:
#        학교명                     도로명주소                     지번주소  \
# 0  성남여자중학교           경상북도 영천시 남촌길 17        경상북도 영천시 도동 213-1
# 1  금호여자중학교  경상북도 영천시 금호읍 성천앞길 112-53  경상북도 영천시 금호읍 대미리 930-23
#
#                  경도                위도     법정동명  법정동  법정리        법정코드
# 0  128.931796241655  35.9492794015542       도동  남부동   도동  4723011100
# 1  128.878647120825  35.9394567070447  금호읍 대미리  금호읍  교대리  4723025021

# %% [markdown]
# ##지도시각화

# %%
#지도 시각화
import folium

# %%
def map_visualization(data):
  m = folium.Map([37,127],zoom_start=5)
  for i in range(len(data)):
    folium.Marker([data['위도'][i],data['경도'][i]],
                  popup=data['병원명'][i]).add_to(m)
  return m

# %%
map_visualization(emergency_medical)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ##최종 데이터프레임 저장

# %%
pub_medical.to_csv("20210726_영천시_보건소보건의료원_final.csv",index=False)
emergency_medical.to_csv("20220826_영천시_응급의료기관_final.csv", index=False)
kindergarden.to_csv("어린이집_final.csv",index=False)
child.to_csv("유치원_final.csv", index=False)
middle_school.to_csv('중학교_final.csv', index=False)

# %%
air.to_csv("대기오염(2021~2017)", index=False)

# %%
flourishing.to_csv("활성화지수(2013~2021).csv", index=False)

# %%
산업.to_csv("산업별지표(2015).csv", index=False)

# %%
people_percent.to_csv("년도별 인구비율", index=False)

# %%
people.to_csv("년도별 인구", index=False)
